# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-59509ec7-fd43-4740-9ea8-9f85ed5e1eb3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-59509ec7-fd43-4740-9ea8-9f85ed5e1eb3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nasdaq_screener_1625082841915.csv to nasdaq_screener_1625082841915.csv
# {'nasdaq_screener_1625082841915.csv': b"Symbol,Name,Last Sale,Net Change,% Change,Market Cap,Country,IPO Year,Volume,Sector,Industry\r\nA,Agilent Technologies Inc. Common Stock,$147.59,-1.22,-0.82%,44785185578.00,United States,1999,578403,Capital Goods,Electrical Products\r\nAA,Alcoa Corporation Common Stock ,$36.855,-0.675,-1.799%,6881740477.00,,2016,4874720,Basic Industries,Metal Fabrications\r\nAAC,Ares Acquisition Corporation Class A Ordinary Shares,$9.7799,0.0099,0.101%,1222487500.00,,2021,17117,Finance,Business Services\r\nAACG,ATA Creativity Global American Depositary Shares,$3.05,-0.03,-0.974%,96688623.00,China,,69165,Miscellaneous,Service to the Health Industry\r\nAAIC,Arlington Asset Investment Corp Class A (new),$4.07,-0.13,-3.095%,136268407.00,United States,,164415,Finance,Finance/Investors Services\r\nAAIC^B,Arlington Asset Investment Corp 7.00% ,$24.80,0.00,0.00%,,United States,,138,,\r\nAAIC^C,Arlington Asset Investment Corp 8.250% Seies C Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock   ,$25.01,-0.13,-0.517%,,United States,,318,,\r\nAAL,American Airlines Group Inc. Common Stock,$21.17,0.09,0.427%,13578080714.00,United States,,21302167,Transportation,Air Freight/Delivery Services\r\nAAMC,Altisource Asset Management Corp Com,$19.25,0.00,0.00%,39430141.00,United States,,27,Finance,Investment Managers\r\nAAME,Atlantic American Corporation Common Stock,$4.36,-0.0047,-0.108%,89012810.00,United States,,24130,Finance,Life Insurance\r\nAAN,Aarons Holdings Company Inc. Common Stock ,$32.15,-0.65,-1.982%,1155238138.00,United States,2020,193123,Miscellaneous,Diversified Commercial Services\r\nAAOI,Applied Optoelectronics Inc. Common Stock,$8.48,-0.19,-2.191%,227790506.00,United States,2013,379466,Technology,Semiconductors\r\nAAON,AAON Inc. Common Stock,$63.06,-0.70,-1.098%,3306561631.00,United States,,206385,Capital Goods,Industrial Machinery/Components\r\nAAP,Advance Auto Parts Inc Advance Auto Parts Inc W/I,$205.49,0.19,0.093%,13447033396.00,United States,,343518,Consumer Services,Other Specialty Stores\r\nAAPL,Apple Inc. Common Stock,$137.29,0.96,0.704%,2380243408600.00,United States,1980,42460757,Technology,Computer Manufacturing\r\nAAQC,Accelerate Acquisition Corp. Class A Common Stock,$9.69,-0.0118,-0.122%,484500000.00,,2021,2930,,\r\nAAT,American Assets Trust Inc. Common Stock,$37.37,0.21,0.565%,2259849328.00,United States,2011,87017,Consumer Services,Real Estate Investment Trusts\r\nAAU,Almaden Minerals Ltd. Common Shares,$0.5012,0.0132,2.705%,68775370.00,Canada,2015,352096,Basic Industries,Precious Metals\r\nAAWW,Atlas Air Worldwide Holdings NEW Common Stock,$68.09,-0.30,-0.439%,1975210213.00,United States,,204206,Transportation,Transportation Services\r\nAB,AllianceBernstein Holding L.P.  Units,$46.375,0.235,0.509%,4660216747.00,United States,,207243,Finance,Investment Managers\r\nABB,ABB Ltd Common Stock,$33.935,-0.575,-1.666%,68209496430.00,Switzerland,,1182959,Consumer Durables,Electrical Products\r\nABBV,AbbVie Inc. Common Stock,$112.66,0.36,0.321%,198982608374.00,United States,2012,2784647,Health Care,Major Pharmaceuticals\r\nABC,AmerisourceBergen Corporation Common Stock,$113.83,-0.61,-0.533%,23609561916.00,United States,,442248,Health Care,Other Pharmaceuticals\r\nABCB,Ameris Bancorp Common Stock,$50.70,0.02,0.039%,3535383298.00,United States,1994,189863,Finance,Major Banks\r\nABCL,AbCellera Biologics Inc. Common Shares,$22.275,0.995,4.676%,6034874155.00,Canada,2020,1775360,,\r\nABCM,Abcam plc American Depositary Shares,$18.94,-0.59,-3.021%,4294601798.00,United Kingdom,2020,530268,Health Care,Biotechnology: Biological Products (No Diagnostic Substances)\r\nABEO,Abeona Therapeutics Inc. Common Stock,$1.565,-0.075,-4.573%,156332024.00,United States,,714865,Health Care,Major Pharmaceuticals\r\nABEV,Ambev S.A. American Depositary Shares (Each representing 1 Common Share),$3.43,-0.06,-1.719%,53977591631.00,,2013,23276859,Consumer Non-Durables,Beverages (Production/Distribution)\r\nABG,Asbury Autom ...

# %%
import pandas
dataframe = pandas.read_csv("nasdaq_screener_1625082841915.csv")
print(dataframe)
# Out:
#      Symbol  ...                                           Industry
# 0         A  ...                                Electrical Products
# 1        AA  ...                                 Metal Fabrications
# 2       AAC  ...                                  Business Services
# 3      AACG  ...                     Service to the Health Industry
# 4      AAIC  ...                         Finance/Investors Services
# ...     ...  ...                                                ...
# 7888  ZWRKW  ...                                  Business Services
# 7889     ZY  ...  Biotechnology: Commercial Physical & Biologica...
# 7890   ZYME  ...                                                NaN
# 7891   ZYNE  ...                              Major Pharmaceuticals
# 7892   ZYXI  ...  Biotechnology: Electromedical & Electrotherape...
#
# [7893 rows x 11 columns]

# %%
dataframe.head()
# Out:
#   Symbol  ...                        Industry
# 0      A  ...             Electrical Products
# 1     AA  ...              Metal Fabrications
# 2    AAC  ...               Business Services
# 3   AACG  ...  Service to the Health Industry
# 4   AAIC  ...      Finance/Investors Services
#
# [5 rows x 11 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7893 entries, 0 to 7892
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      7893 non-null   object
#  1   Name        7893 non-null   object
#  2   Last Sale   7893 non-null   object
#  3   Net Change  7893 non-null   float64
#  4   % Change    7887 non-null   object
#  5   Market Cap  7265 non-null   float64
#  6   Country     7170 non-null   object
#  7   IPO Year    4580 non-null   float64
#  8   Volume      7893 non-null   int64
#  9   Sector      6299 non-null   object
#  10  Industry    6298 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 678.4+ KB

# %%
dataframe.describe()
# Out:
#         Net Change    Market Cap     IPO Year        Volume
# count  7893.000000  7.265000e+03  4580.000000  7.893000e+03
# mean      0.112121  9.299767e+09  2013.951965  9.246592e+05
# std       9.384613  7.071632e+10     9.164406  7.352660e+06
# min     -24.000000  0.000000e+00  1972.000000  1.000000e+00
# 25%      -0.100000  1.029356e+08  2012.000000  1.938400e+04
# 50%       0.000000  5.010655e+08  2018.000000  1.048170e+05
# 75%       0.130000  3.110762e+09  2020.000000  4.197700e+05
# max     819.010000  3.284086e+12  2021.000000  4.132443e+08

# %%
# !pip install jupyter-dash
# !pip install dash
# Out:
# Collecting jupyter-dash
#   Downloading https://files.pythonhosted.org/packages/46/21/d3893ad0b7a7061115938d6c38f5862522d45c4199fb7e8fde0765781e13/jupyter_dash-0.4.0-py3-none-any.whl
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (5.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (2.23.0)
# Collecting dash
#   Downloading https://files.pythonhosted.org/packages/d4/50/e7c2830168db186f84b7de2988543e974433a6cdb0a0b23d51c781e2b2ab/dash-1.20.0.tar.gz (77kB)
#      |████████████████████████████████| 81kB 2.7MB/s
# Collecting ansi2html
#   Downloading https://files.pythonhosted.org/packages/c6/85/3a46be84afbb16b392a138cd396117f438c7b2e91d8dc327621d1ae1b5dc/ansi2html-1.6.0-py3-none-any.whl
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (4.10.1)
# Requirement already satisfied: retrying in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (from jupyter-dash) (1.1.4)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (57.0.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (5.0.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash) (2.6.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->jupyter-dash) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->jupyter-dash) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->jupyter-dash) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->jupyter-dash) (2021.5.30)
# Collecting flask-compress
#   Downloading https://files.pythonhosted.org/packages/75/fa/a3c96f3f367ad1d6532fa8394c9a6f5879513868207096f6b41f4168b342/Flask_Compress-1.10.1-py3-none-any.whl
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from dash->jupyter-dash) (4.4.1)
# Collecting dash_renderer==1.9.1
#   Downloading https://files.pythonhosted.org/packages/5f/d3/d661a68b4ce71498d5c0c79617bce3d5fc884d4448c698f77c2247cd1b46/dash_renderer-1.9.1.tar.gz (1.0MB)
#      |████████████████████████████████| 1.0MB 21.5MB/s
# Collecting dash-core-components==1.16.0
#   Downloading https://files.pythonhosted.org/packages/f4/79/434e14d77dbf82b27f98df077936a424de254059d47152b0445b7116e97e/dash_core_components-1.16.0.tar.gz (3.5MB)
#      |████████████████████████████████| 3.5MB 34.5MB/s
# Collecting dash-html-components==1.1.3
#   Downloading https://files.pythonhosted.org/packages/8f/ca/7eeca4cae4e15cc6f7d0bc41a46368dd3fcdddc72aaa5bac61a8b92d541c/dash_html_components-1.1.3.tar.gz (82kB)
#      |████████████████████████████████| 92kB 8.3MB/s
# Collecting dash-table==4.11.3
#   Downloading https://files.pythonhosted.org/packages/97/f7/f4969a926f20a55d3e5970d01b85ff9ad510dba32de189e72dd8f4992740/dash_table-4.11.3.tar.gz (1.8MB)
#      |████████████████████████████████| 1.8MB 37.8MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from dash->jupyter-dash) (0.16.0)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter-dash) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter-dash) (5.3.5)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from retrying->jupyter-dash) (1.15.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask->jupyter-dash) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask->jupyter-dash) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask->jupyter-dash) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask->jupyter-dash) (1.1.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from traitlets>=4.2->ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect; sys_platform != "win32"->ipython->jupyter-dash) (0.7.0)
# Collecting brotli
#   Downloading https://files.pythonhosted.org/packages/15/ea/5bd575511b37bbd1c794606a0a621e6feff8e96b7dd007a86a5d218b2d94/Brotli-1.0.9-cp37-cp37m-manylinux1_x86_64.whl (357kB)
#      |████████████████████████████████| 358kB 39.0MB/s
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (22.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask->jupyter-dash) (2.0.1)
# Building wheels for collected packages: dash, dash-renderer, dash-core-components, dash-html-components, dash-table
#   Building wheel for dash (setup.py) ... done
#   Created wheel for dash: filename=dash-1.20.0-cp37-none-any.whl size=85845 sha256=7013681d8d9a759db0a3bfddadd53dbb5213f9c9917b2f622505949a2c8eb7c0
#   Stored in directory: /root/.cache/pip/wheels/e6/33/41/ce361d0d1da277d2350f815b10f2ab1e331592d93ef2b07e29
#   Building wheel for dash-renderer (setup.py) ... done
#   Created wheel for dash-renderer: filename=dash_renderer-1.9.1-cp37-none-any.whl size=1014873 sha256=2630af63a6fa3bdee658204ee08fc973c47c4ae6394115475457f2490ed980c3
#   Stored in directory: /root/.cache/pip/wheels/03/a9/c5/dd5815c601b0ede164c223ffd7bafebde716ca57de06ef8aec
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-1.16.0-cp37-none-any.whl size=3540992 sha256=b34036fa14249254eadc9a9f861a6a0ea42a1f0892cee79e65d37c42a4c3d092
#   Stored in directory: /root/.cache/pip/wheels/86/1e/8c/e87ebba30b73c20dcd641224274febc983af88ed0fd7712a07
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.3-cp37-none-any.whl size=319488 sha256=99e987d6b0232f25f5708a73663c713f9efbf2ba7b011800668808b31f916a4a
#   Stored in directory: /root/.cache/pip/wheels/07/f9/6c/f9b73a6ae1b7f347a92dc240293cebc267b370ba2a80added2
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-4.11.3-cp37-none-any.whl size=1827623 sha256=a71b04a4b2fcc9ad3b5467ad4d7d7b03106b470253d7d3126ec61d99ae7e3f92
#   Stored in directory: /root/.cache/pip/wheels/51/9b/89/374be1bc250e28a15edbd657cf364f163e392ba5257bfd0e87
# Successfully built dash dash-renderer dash-core-components dash-html-components dash-table
# Installing collected packages: brotli, flask-compress, dash-renderer, dash-core-components, dash-html-components, dash-table, dash, ansi2html, jupyter-dash
# Successfully installed ansi2html-1.6.0 brotli-1.0.9 dash-1.20.0 dash-core-components-1.16.0 dash-html-components-1.1.3 dash-renderer-1.9.1 dash-table-4.11.3 flask-compress-1.10.1 jupyter-dash-0.4.0
# Requirement already satisfied: dash in /usr/local/lib/python3.7/dist-packages (1.20.0)
# Requirement already satisfied: flask-compress in /usr/local/lib/python3.7/dist-packages (from dash) (1.10.1)
# Requirement already satisfied: dash-renderer==1.9.1 in /usr/local/lib/python3.7/dist-packages (from dash) (1.9.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from dash) (0.16.0)
# Requirement already satisfied: dash-html-components==1.1.3 in /usr/local/lib/python3.7/dist-packages (from dash) (1.1.3)
# Requirement already satisfied: dash-table==4.11.3 in /usr/local/lib/python3.7/dist-packages (from dash) (4.11.3)
# Requirement already satisfied: dash-core-components==1.16.0 in /usr/local/lib/python3.7/dist-packages (from dash) (1.16.0)
# Requirement already satisfied: Flask>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from dash) (1.1.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from dash) (4.4.1)
# Requirement already satisfied: brotli in /usr/local/lib/python3.7/dist-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly->dash) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly->dash) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=1.0.4->dash) (2.0.1)

# %%
# Stock and Date Range Pickers

from jupyter_dash import JupyterDash

import dash

import dash_html_components as html

import dash_core_components as dcc

from datetime import datetime

app = JupyterDash(__name__)

options = []

for element in dataframe.index:

  options.append({"label": dataframe["Name"][element],
                  "value": dataframe["Symbol"][element]
                  })

app.layout = html.Div([
                       html.H1("Stock Ticker Web App"),
                       html.Div([
                                 html.H2("Select a stock:"),
                                 dcc.Dropdown(
                                     id = "dropdown",
                                     options = options,
                                     value = ["GOOG"],
                                     multi = True
                                 )
                       ]),
                       html.Div([
                                 html.H2("Select Date"),
                                 dcc.DatePickerRange(
                                     id = "datepicker",
                                     min_date_allowed = datetime(2017, 
                                                                 1, 
                                                                 1),
                                     max_date_allowed = datetime.today(),
                                     start_date = datetime(2020, 1, 1),
                                     end_date = datetime.today()
                                 )
                       ]),
                       html.Div([
                                 html.Button(
                                     id = "submit-button",
                                     n_clicks = 0,
                                     children = "Submit"
                                 )
                       ]),
                       dcc.Graph(
                           id = "stock-graph"
                       )
])

app.run_server(port = 3030)
# Out:
# Dash app running on:

# %%
# Stock data in Web App

app = JupyterDash(__name__)

options = []

for element in dataframe.index:

  options.append({"label": dataframe["Name"][element],
                  "value": dataframe["Symbol"][element]
                  })

app.layout = html.Div([
                       html.H1("Stock Ticker Web App"),
                       html.Div([
                                 html.H2("Select a stock:"),
                                 dcc.Dropdown(
                                     id = "dropdown",
                                     options = options,
                                     value = ["GOOG"],
                                     multi = True
                                 )
                       ]),
                       html.Div([
                                 html.H2("Select Date"),
                                 dcc.DatePickerRange(
                                     id = "datepicker",
                                     min_date_allowed = datetime(2017, 
                                                                 1, 
                                                                 1),
                                     max_date_allowed = datetime.today(),
                                     start_date = datetime(2020, 1, 1),
                                     end_date = datetime.today()
                                 )
                       ]),
                       html.Div([
                                 html.Button(
                                     id = "submit-button",
                                     n_clicks = 0,
                                     children = "Submit"
                                 )
                       ]),
                       dcc.Graph(
                           id = "stock-graph"
                       )
])

from dash.dependencies import Output, Input, State

import pandas

from pandas_datareader import DataReader

@app.callback(Output("stock-graph", "figure"),
              [Input("submit-button", "n_clicks")],
              [State("dropdown", "value"),
               State("datepicker", "start_date"),
               State("datepicker", "end_date")]
              )
def update_graph(number_of_clicks, stocks, start_date, end_date):

  start = datetime.strptime(start_date[:10], "%Y-%m-%d")

  end   = datetime.strptime(end_date[:10], "%Y-%m-%d")

  data = []

  for stock in stocks:

    dataframe = DataReader(stock, "yahoo", start, end)

    dates = []

    for row in range(len(dataframe)):

      new_date = str(dataframe.index[row])

      new_date = new_date[0:10]

      dates.append(new_date)

    dataframe["Date"] = dates

    data.append({
        "x": dataframe["Date"],
        "y": dataframe["Adj Close"],
        "name": stock
    })

  figure = {
      "data": data,
      "layout": { 
          "title": "Stock Data"
      }
  }

  return figure

app.run_server(port = 3030)
# Out:
# Dash app running on:
